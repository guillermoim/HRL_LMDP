# %%
#%matplotlib widget
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '..')
import pickle
from results_functions import *
from matplotlib.ticker import FormatStrFormatter

# %%
results_dir = '../results'
plt.ioff()

# %% [markdown]
# # <span style="color: red;"> High-level MAE for Taxi 5x5 room, lambda 1</span>

# %%
results_dir = '../results_taxi'

filename = 'pictures/overall_taxi_5_1.pdf'

csfont = {'fontname':'Helvetica', 'fontsize':30}
hfont = {'fontname':'Helvetica', 'fontsize':30}

plt.close('all')

fig, ax = plt.subplots(1,1, figsize=(9, 6))

lambda_ = 1

ax.set_title(fr'Taxi, $ 5\times5 $ grid', **csfont)
       
ax.plot(res_v1[2], linewidth=3, markevery=250, color='gray', marker='x', markersize=10)
ax.plot(res_v2[2], linewidth=3, markevery=250, color='brown', marker='d', markersize=10)
ax.plot(res_v3[2], linewidth=3, markevery=250, color='royalblue', marker='^', markersize=10)
ax.plot(res_options, linewidth=3, markevery=250, color='orange', marker='x', markersize=10)
ax.plot(res_plain, linewidth=3, markevery=250, color='black', marker='o', markersize=10)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

legend = ['$V_1$', '$V_2$', '$V_3$', 'Q_o', 'Z-IS']

ax.legend(legend, fontsize=22, loc=1)
ax.set_xlim((0,5000))
ax.set_ylim((0,20))


ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.xaxis.offsetText.set_fontsize(18)

ax.set_ylabel('MAE in $\hat V(s)$', **hfont)
ax.set_xlabel('samples', **hfont)

plt.savefig(filename, bbox_inches='tight', dpi=500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1_/jv66mrwj0w97l7_jd6y4vj8w0000gn/T/ipykernel_9985/1908181107.py in <module>
#      14 ax.set_title(fr'Taxi, $ 5\times5 $ grid', **csfont)
#      15
# ---> 16 ax.plot(res_v1[2], linewidth=3, markevery=250, color='gray', marker='x', markersize=10)
#      17 ax.plot(res_v2[2], linewidth=3, markevery=250, color='brown', marker='d', markersize=10)
#      18 ax.plot(res_v3[2], linewidth=3, markevery=250, color='royalblue', marker='^', markersize=10)
#
# NameError: name 'res_v1' is not defined

# %% [markdown]
# # <span style="color: red;"> High-level MAE for Taxi 10x10 room, lambda 1</span>

# %%
results_dir = '../results_taxi'

res_v1 = get_MAE_HL_errors(f'{results_dir}/taxi_10_v1_333.pkl', '$V_1$-IL', 5000, 10, (8, 5))
res_v2 = get_MAE_HL_errors(f'{results_dir}/taxi_10_v2_333.pkl', '$V_2$-IL', 5000, 10, (8, 5))
res_v3 = get_MAE_HL_errors(f'{results_dir}/taxi_10_v3_333.pkl', '$V_3$-IL', 5000, 10, (8, 5))
res_options = np.loadtxt('../../options/results/TAXI_H_errors_10x10.txt')
res_plain = get_MAE_plain_Z_learning(f'{results_dir}/taxi_10_flat_333.pkl', 'Z-learning+IS', 5000, 10)

filename = 'pictures/overall_taxi_10_1.pdf'

csfont = {'fontname':'Helvetica', 'fontsize':30}
hfont = {'fontname':'Helvetica', 'fontsize':30}

plt.close('all')

fig, ax = plt.subplots(1,1, figsize=(9, 6))

lambda_ = 1

ax.set_title(fr'Taxi, $ 10\times10 $ grid', **csfont)
       
ax.plot(res_v1[2], linewidth=3, markevery=250, color='gray', marker='x', markersize=10)
ax.plot(res_v2[2], linewidth=3, markevery=250, color='brown', marker='d', markersize=10)
ax.plot(res_v3[2], linewidth=3, markevery=250, color='royalblue', marker='^', markersize=10)
ax.plot(res_options, linewidth=3, markevery=250, color='orange', marker='x', markersize=10)
ax.plot(res_plain, linewidth=3, markevery=250, color='black', marker='o', markersize=10)

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

legend = ['$V_1$', '$V_2$', '$V_3$', '$Q_o$', 'Z-IS']

ax.legend(legend, fontsize=22, loc=1)
ax.set_xlim((0,10000))
ax.set_ylim((0,41))

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.xaxis.offsetText.set_fontsize(18)

ax.set_ylabel('MAE in $\hat V(s)$', **hfont)
ax.set_xlabel('samples', **hfont)

plt.savefig(filename, bbox_inches='tight', dpi=500)
plt.show()

# %% [markdown]
# # <span style="color: red;"> High-level MAE for Gridworld 3x3 lambda 1</span>

# %%
results_dir = '../results'
res_v1 = get_MAE_HL_errors(f'{results_dir}/grid_3_3_v1_0.pkl', '$V_1$-IL', 5000, 10, (8, 5), key=(5000,500))
res_v2 = get_MAE_HL_errors(f'{results_dir}/grid_3_3_v2_0.pkl', '$V_2$-IL', 5000, 10, (8, 5), key=(5000,500))
res_v3 = get_MAE_HL_errors(f'{results_dir}/grid_3_3_v3_0.pkl', '$V_3$-IL', 5000, 10, (8, 5), key=(5000,500))
res_options = np.loadtxt('../../options/results/rooms_H_errors_3x3.txt')
res_plain = get_MAE_plain_Z_learning(f'{results_dir}/grid_3_3_flat_0.pkl', 'Z-learning+IS', 5000, 10)

filename = 'pictures/overall_grid_3_3_1.pdf'

csfont = {'fontname':'Helvetica', 'fontsize':30}
hfont = {'fontname':'Helvetica', 'fontsize':30}

plt.close('all')

fig, ax = plt.subplots(1,1, figsize=(9, 6))

lambda_ = 1

ax.set_title(fr'$ 3\times3$ rooms, room size = $5\times 5$', **csfont)
       
ax.plot(res_v1[2], linewidth=3, markevery=250, color='gray', marker='x', markersize=10)
ax.plot(res_v2[2], linewidth=3, markevery=250, color='brown', marker='d', markersize=10)
ax.plot(res_v3[2], linewidth=3, markevery=250, color='royalblue', marker='^', markersize=10)
ax.plot(res_options, linewidth=3, markevery=250, color='orange', marker='x', markersize=10)
ax.plot(res_plain, linewidth=3, markevery=250, color='black', marker='o', markersize=10)

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

legend = ['$V_1$', '$V_2$', '$V_3$', '$Q_o$', 'Z-IS']

ax.legend(legend, fontsize=22, loc=1)
ax.set_xlim((0,5000))
ax.set_ylim((0,30))

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.xaxis.offsetText.set_fontsize(18)

ax.set_ylabel('MAE in $\hat V(s)$', **hfont)
ax.set_xlabel('samples', **hfont)

plt.savefig(filename, bbox_inches='tight', dpi=500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/1_/jv66mrwj0w97l7_jd6y4vj8w0000gn/T/ipykernel_9985/3349195486.py in <module>
#       4 res_v3 = get_MAE_HL_errors(f'{results_dir}/grid_3_3_v3_0.pkl', '$V_3$-IL', 5000, 10, (8, 5), key=(5000,500))
#       5 res_options = np.loadtxt('../../options/results/rooms_H_errors_3x3.txt')
# ----> 6 res_plain = get_MAE_plain_Z_learning(f'{results_dir}/grid_3_3_flat_0.pkl', 'Z-learning+IS', 5000, 10)
#       7
#       8 filename = 'pictures/overall_grid_3_3_1.pdf'
#
# ~/Desktop/SAFE_PROJECTS/research/notebooks/results_functions.py in get_MAE_plain_Z_learning(path, title, xlim, ylim)
#      49 def get_MAE_plain_Z_learning(path, title, xlim, ylim):
#      50
# ---> 51     aux = pickle.load(open(path, 'rb'))
#      52     res = {k:aux[k][1] for k in aux}
#      53
#
# ...

# %% [markdown]
# # <span style="color: red;"> High-level MAE for Gridworld 5x5 lambda 1</span>

# %%
results_dir = '../results_grid_5_5_3'
res_v1 = get_MAE_HL_errors(f'{results_dir}/grid_5_5_1_3_v1_444.pkl', '$V_1$-IL', 5000, 10, (8, 5))
res_v2 = get_MAE_HL_errors(f'{results_dir}/grid_5_5_1_3_v2_444.pkl', '$V_2$-IL', 5000, 10, (8, 5))
res_v3 = get_MAE_HL_errors(f'{results_dir}/grid_5_5_1_3_v3_444.pkl', '$V_3$-IL', 5000, 10, (8, 5))
res_flat = np.loadtxt('../../options/results/rooms_Flat_errors_5x5.txt')
res_options = np.loadtxt('../../options/results/rooms_H_errors_5x5.txt')
res_plain = get_MAE_plain_Z_learning(f'{results_dir}/grid_5_5_1_3_flat_444.pkl', 'Z-learning+IS', 5000, 100)
filename = 'pictures/overall_grid_5_5_1_3.pdf'

csfont = {'fontname':'Helvetica', 'fontsize':30}
hfont = {'fontname':'Helvetica', 'fontsize':30}

plt.close('all')

fig, ax = plt.subplots(1,1, figsize=(9, 6))

lambda_ = 1

ax.set_title(fr'$ 5\times5$ rooms, room size = $3\times 3$', **csfont)
       
ax.plot(res_v1[2], linewidth=3, markevery=250, color='gray', marker='x', markersize=10)
ax.plot(res_v2[2], linewidth=3, markevery=250, color='brown', marker='d', markersize=10)
ax.plot(res_v3[2], linewidth=3, markevery=250, color='royalblue', marker='^', markersize=10)
ax.plot(res_options, linewidth=3, markevery=250, color='orange', marker='x', markersize=10)
ax.plot(res_plain, linewidth=3, markevery=250, color='black', marker='o', markersize=10)

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

legend = ['$V_1$', '$V_2$', '$V_3$', '$Q_o$', 'Z-IS']

ax.legend(legend, fontsize=22)
ax.set_xlim((0,10000))
ax.set_ylim((0,31))


ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.xaxis.offsetText.set_fontsize(18)

ax.set_ylabel('MAE in $\hat V(s)$', **hfont)
ax.set_xlabel('samples', **hfont)

plt.savefig(filename, bbox_inches='tight', dpi=500)
plt.show()

# %% [markdown]
# # <span style="color: red;"> High-level MAE for Gridworld 8x8 lambda 1</span>

# %%
results_dir = '../results_grid_8_8'
res_v1 = get_MAE_HL_errors(f'{results_dir}/grid_8_8_1_v1_333.pkl', '$V_1$-IL', 5000, 10, (8, 5))
res_v2 = get_MAE_HL_errors(f'{results_dir}/grid_8_8_1_v2_333.pkl', '$V_2$-IL', 5000, 10, (8, 5))
res_v3 = get_MAE_HL_errors(f'{results_dir}/grid_8_8_1_v3_333.pkl', '$V_3$-IL', 5000, 10, (8, 5))
res_options = np.loadtxt('../../options/results/rooms_H_errors_8x8.txt')
res_plain = get_MAE_plain_Z_learning(f'{results_dir}/grid_8_8_1_flat_333.pkl', 'Z-learning+IS', 5000, 100)
filename = 'pictures/overall_grid_8_8_1.pdf'

csfont = {'fontname':'Helvetica', 'fontsize':30}
hfont = {'fontname':'Helvetica', 'fontsize':30}

plt.close('all')

fig, ax = plt.subplots(1,1, figsize=(9, 6))

lambda_ = 1

ax.set_title(fr'$ 8\times8$ rooms, room size = $5\times 5$', **csfont)
       
ax.plot(res_v1[2], linewidth=3, markevery=250, color='gray', marker='x', markersize=10)
ax.plot(res_v2[2], linewidth=3, markevery=250, color='brown', marker='d', markersize=10)
ax.plot(res_v3[2], linewidth=3, markevery=250, color='royalblue', marker='^', markersize=10)
ax.plot(res_options, linewidth=3, markevery=250, color='orange', marker='x', markersize=10)
ax.plot(res_plain, linewidth=3, markevery=250, color='black', marker='o', markersize=10)

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

legend = ['$V_1$', '$V_2$', '$V_3$', '$Q_o$', 'Z-IS']

ax.legend(legend, fontsize=22, loc=1)
ax.set_xlim((0,15000))
ax.set_ylim((0,84))


ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.xaxis.offsetText.set_fontsize(18)

ax.set_ylabel('MAE in $\hat V(s)$', **hfont)
ax.set_xlabel('samples', **hfont)

plt.savefig(filename, bbox_inches='tight', dpi=500)
plt.show()

# %%
Z_true = pickle.load(open('../configs_grid/5_5_1_3.dict', 'rb'))['Z_true']
#plotmat(np.log(Z_true[:225]).reshape(15,15), 'TRUE', annotated=True, figsize=(9,9))
Z_true.shape

# %%
#plot_gridworld_2(np.log(z1).reshape(5,5), '$\hat V(s)$ v$_3$', annotated=False, figsize=(9,9))
#plt.show()

# %%
sol = pickle.load(open('../configs_taxi/taxi_3_3_1.dict', 'rb'))
states, Z = sol['states'], sol['Z_true']

plot_taxi(Z, states, ((0,0), (4,4)), 5, 'Passenger at (0,0) and destination at (4,4)', figsize=(10,10), annotated=False, save_path='taxi_domain')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-98669ed2b47a> in <module>
# ----> 1 sol = pickle.load(open('../configs_taxi/taxi_3_3_1.dict', 'rb'))
#       2 states, Z = sol['states'], sol['Z_true']
#       3
#       4 plot_taxi(Z, states, ((0,0), (4,4)), 5, 'Passenger at (0,0) and destination at (4,4)', figsize=(10,10), annotated=False, save_path='taxi_domain')
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '../configs_taxi/taxi_3_3_1.dict'

# %%
a = np.ones((4,4))

# %% [markdown]
# ## Low level

# %%
results_dir = '../results'
res_v1 = get_MAE_LL_errors(f'{results_dir}/grid_3_3_v1_0.pkl', '$V_1$-IL', 5000, 10, (8, 5))

csfont = {'fontname':'Helvetica', 'fontsize':30}
hfont = {'fontname':'Helvetica', 'fontsize':30}

plt.close('all')

fig, ax = plt.subplots(1,1, figsize=(9, 6))

lambda_ = 1

ax.set_title(fr'$ 8\times8$ rooms, room size = $5\times 5$', **csfont)
       
ax.plot(res_v1[3], linewidth=3, markevery=250, color='gray', marker='x', markersize=10)

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

legend = ['$V_1$']

ax.legend(legend, fontsize=22, loc=1)
ax.set_xlim((0,15000))
ax.set_ylim((0,84))


ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.xaxis.offsetText.set_fontsize(18)

ax.set_ylabel('MAE in $\hat V(s)$', **hfont)
ax.set_xlabel('samples', **hfont)

plt.savefig(filename, bbox_inches='tight', dpi=500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1_/jv66mrwj0w97l7_jd6y4vj8w0000gn/T/ipykernel_14574/3950688059.py in <module>
#      13 ax.set_title(fr'$ 8\times8$ rooms, room size = $5\times 5$', **csfont)
#      14
# ---> 15 ax.plot(res_v1[3], linewidth=3, markevery=250, color='gray', marker='x', markersize=10)
#      16
#      17 plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
#
# TypeError: 'NoneType' object is not subscriptable

# %%
results_dir = '../results'
get_MAE_HL_errors(f'{results_dir}/grid_3_3_v1_0.pkl', '$V_1$-IL', 5000, 10, (8, 5))
#get_MAE_HL_errors(f'{results_dir}/grid_3_3_v2_0.pkl', '$V_1$-IL', 5000, 10, (8, 5))

plt.show()
